# %% [markdown]
# # Common Libraries

# %%
import os
import sys
from glob import glob

# %% [markdown]
# # Custom Libraries

# %%
is_use_source = False
if is_use_source:
    os.environ["easysurfvis_isRunSource"] = "True"
    os.environ["easysurfvis_source_home"] = "/home/seojin/easy_surf_vis/src/easysurfvis"
    sys.path.append(os.getenv("easysurfvis_source_home"))
    from cores.surface_data import load_surfData_fromVolume, sample_dir_path
else:
    from easysurfvis.cores.surface_data import load_surfData_fromVolume, sample_dir_path

# %% [markdown]
# # Load data

# %%
volume_data_paths = sorted(glob(os.path.join(sample_dir_path, "*.nii.gz")))

# Convert 3d map data -> surface map data
l_surf_data_onMove = load_surfData_fromVolume(volume_data_paths, hemisphere = "L")
r_surf_data_onMove = load_surfData_fromVolume(volume_data_paths, hemisphere = "R")
print(f"loaded: {volume_data_paths}")
# Out:
# loaded: ['/home/seojin/easy_surf_vis/src/easysurfvis/data/Sample/sample_3d_data.nii.gz']
