# %% [markdown]
# # Common Libraries

# %%
import os
import sys
from glob import glob

# %% [markdown]
# # Custom Libraries

# %%
import easysurfvis

# %%
easysurfvis
# Out:
# <module 'easysurfvis' from '/home/seojin/anaconda3/envs/surfVis/lib/python3.10/site-packages/easysurfvis/__init__.py'>

# %%
sys.path.append(os.path.join(str(Path.cwd().parent), "src", "easysurfvis", "cores"))

from surface_data import load_surfData_fromVolume, sample_dir_path

# %% [markdown]
# # Load data

# %%
volume_data_paths = sorted(glob(os.path.join(sample_dir_path, "*.nii.gz")))

# Convert 3d map data -> surface map data
l_surf_data_onMove = load_surfData_fromVolume(volume_data_paths, hemisphere = "L")
r_surf_data_onMove = load_surfData_fromVolume(volume_data_paths, hemisphere = "R")
print(f"loaded: {volume_data_paths}")
# Out:
# loaded: ['/home/seojin/easy_surf_vis/data/Sample/sample_3d_data.nii.gz']

# %%
sample_dir_path
# Out:
# '/home/seojin/easy_surf_vis/data/Sample'
