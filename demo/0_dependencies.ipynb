# %% [markdown]
# # Checked version
#
# - python <= 3.12
# - matplotlib == 3.10.8

# %% [markdown]
# # Dependenceis

# %%
# !pip install SUITPy
# !pip install neuroimagingtools
# !pip install nibabel
# !pip install nilearn
# !pip install opencv-python
# !pip install flask flask-cors
