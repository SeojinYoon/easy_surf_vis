# %% [markdown]
# # Common Libraries

# %%
import os
import sys
import json
import numpy as np
from pathlib import Path

# %% [markdown]
# # Custom Libraries

# %%
sys.path.append(os.path.join(str(Path.cwd().parent), "src", "easysurfvis", "cores"))
from surface_data import roi_dir_path

sys.path.append(os.path.join(str(Path.cwd().parent), "src", "easysurfvis"))
from surface_visualization import draw_surf_selectedROI, draw_surf_roi, show_both_rois

# %% [markdown]
# # Params

# %%
atlas = "FAN"
save_dir_path = "/mnt/ext1/seojin/temp"

# %% [markdown]
# # Load Datas

# %%
atlas_dir_path = os.path.join(roi_dir_path, atlas)
# ROI values
l_roi_values = np.load(os.path.join(roi_dir_path, atlas, f"L_roi_values.npy"))
r_roi_values = np.load(os.path.join(roi_dir_path, atlas, f"R_roi_values.npy"))

l_roi_labels = np.load(os.path.join(roi_dir_path, atlas, f"L_rois.npy"))
r_roi_labels = np.load(os.path.join(roi_dir_path, atlas, f"R_rois.npy"))

# ROI text locations
with open(os.path.join(roi_dir_path, atlas, f"L_roi_vertex_info.json"), 'rb') as f:
    l_roi_info = json.load(f)
with open(os.path.join(roi_dir_path, atlas, f"R_roi_vertex_info.json"), 'rb') as f:
    r_roi_info = json.load(f)

# %% [markdown]
# # Single hemi

# %%
draw_surf_roi(l_roi_values, l_roi_info, "L")
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
print(np.unique(l_roi_labels))
draw_surf_selectedROI(l_roi_labels, "|Lt_postcentral|", "L")

# %%
draw_surf_roi(r_roi_values, r_roi_info, "R")
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
print(np.unique(r_roi_labels))
draw_surf_selectedROI(r_roi_labels, "|Rt_postcentral|", "R")
# Out:
# ['|' '|Rt_cingulate|' '|Rt_fusiform|' '|Rt_inferior_frontal_gyrus|'
#  '|Rt_inferior_parietal|' '|Rt_inferior_temporal|' '|Rt_insular|'
#  '|Rt_lateral_occipital|' '|Rt_medioventral_occipital|'
#  '|Rt_middle_frontal_gyrus|'
#  '|Rt_middle_frontal_gyrus|Rt_inferior_frontal_gyrus|'
#  '|Rt_middle_temporal|' '|Rt_orbital|' '|Rt_paracentral|'
#  '|Rt_postcentral|' '|Rt_postcentral|Rt_superior_parietal|'
#  '|Rt_precentral|' '|Rt_precuneus|' '|Rt_superior_frontal_gyrus|'
#  '|Rt_superior_parietal|' '|Rt_superior_temporal|'
#  '|Rt_superior_temporal|Rt_middle_temporal|']
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %% [markdown]
# # Both hemi

# %%
show_both_rois(l_roi_values, r_roi_values, l_roi_info, r_roi_info, save_dir_path)
# Out:
# save: /mnt/ext1/seojin/temp/L_hemi_roi.png
# save: /mnt/ext1/seojin/temp/R_hemi_roi.png
# save: /mnt/ext1/seojin/temp/both_hemi_roi.png
# (<Figure size 640x480 with 1 Axes>, <Axes: >)
